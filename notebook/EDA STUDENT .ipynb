# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('data/Student_performance_data _.csv')

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.shape
# Out:
# (2392, 15)

# %%
df.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
df.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.nunique()
# Out:
# StudentID            2392
# Age                     4
# Gender                  2
# Ethnicity               4
# ParentalEducation       5
# StudyTimeWeekly      2392
# Absences               30
# Tutoring                2
# ParentalSupport         5
# Extracurricular         2
# Sports                  2
# Music                   2
# Volunteering            2
# GPA                  2371
# GradeClass              5
# dtype: int64

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
print("catergories in 'Gender' variable    ",end=" ")
print(df['Gender'].unique())

print("catergories in 'Age' variable    ",end=" ")
print(df['Age'].unique())

print("catergories in 'ParentalEducation' variable    ",end=" ")
print(df['ParentalEducation'].unique())

print("catergories in 'StudyTimeWeekly' variable    ",end=" ")
print(df['StudyTimeWeekly'].unique())

print("catergories in 'Absences' variable    ",end=" ")
print(df['Absences'].unique())
# Out:
# catergories in 'Gender' variable     [1 0]
# catergories in 'Age' variable     [17 18 15 16]
# catergories in 'ParentalEducation' variable     [2 1 3 4 0]
# catergories in 'StudyTimeWeekly' variable     [19.83372281 15.40875606  4.21056977 ...  6.80549964 12.41665266
#  17.81990749]
# catergories in 'Absences' variable     [ 7  0 26 14 17 10 22  1 11 15 21  9 16 29  2 25 20  5  8 12 27 23  3 13
#   6 28  4 18 19 24]

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype!='O']
categorical_features = [feature for feature in df.columns if df[feature].dtype!='O']

# %%
numeric_features
# Out:
# ['StudentID',
#  'Age',
#  'Gender',
#  'Ethnicity',
#  'ParentalEducation',
#  'StudyTimeWeekly',
#  'Absences',
#  'Tutoring',
#  'ParentalSupport',
#  'Extracurricular',
#  'Sports',
#  'Music',
#  'Volunteering',
#  'GPA',
#  'GradeClass']

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 4        17         1                3                0       0      0
# 5         0         0                1                1       0      0
# 6        10         0                3                0       1      0
# 7        22         1                1                1       0      0
# 8         1         0                2                0       1      0
#
#    Volunteering       GPA  GradeClass
# 4             0  1.288061         4.0
# ...

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Absences  Tutoring       GPA  GradeClass
# 4       1005   17       1        17         1  1.288061         4.0
# 5       1006   18       0         0         0  3.084184         1.0
# 6       1007   15       0        10         0  2.748237         2.0
# 7       1008   15       1        22         1  1.360143         4.0
# 8       1009   17       0         1         0  2.896819         2.0

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype!='O']
categorical_features = [feature for feature in df.columns if df[feature].dtype=='O']

# %%
numeric_features
# Out:
# ['StudentID', 'Age', 'Gender', 'Absences', 'Tutoring', 'GPA', 'GradeClass']

# %%
categorical_features
# Out:
# []
